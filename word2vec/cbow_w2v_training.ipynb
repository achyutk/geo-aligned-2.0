# %%
# !pip install gensim
# !pip install python-Levenshtein

# %%
import gensim
import pandas as pd

# %%
f = open('data/india_corpus.txt', 'r',encoding="utf-8")
sentences=[]
for x in f.readlines():
    sentences.append(x)

# close the file
f.close()

# %%
df= pd.DataFrame({'sentences':sentences})
review_text = df['sentences'].apply(gensim.utils.simple_preprocess)

# %%
model=gensim.models.Word2Vec(window=10,min_count=2,workers=4)
model.build_vocab(review_text,progress_per=1000)
model.train(review_text,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (24300463, 31621005)

# %%
model.save('./india_corpus_model.model')

# %%
f = open('data/wiki_corpus.txt', 'r',encoding="utf-8")
sentences=[]
for x in f.readlines():
    sentences.append(x)

# close the file
f.close()

# %%
df= pd.DataFrame({'sentences':sentences})
review_text = df['sentences'].apply(gensim.utils.simple_preprocess)

# %%
model=gensim.models.Word2Vec(window=10,min_count=2,workers=4)
model.build_vocab(review_text,progress_per=1000)
model.train(review_text,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (1059359714, 1362154915)

# %%
model.save('./wiki_corpus_model.model')
